# %%
import pandas as pd
import mysql.connector
from mysql.connector import Error
from dotenv import load_dotenv
import os
from datetime import datetime
from glob import glob
import csv

# Load environment variables
load_dotenv()

FILESS_MYSQL_HOST = os.getenv("FILESS_MYSQL_HOST")
FILESS_MYSQL_PORT = int(os.getenv("FILESS_MYSQL_PORT"))
FILESS_MYSQL_USER = os.getenv("FILESS_MYSQL_USER")
FILESS_MYSQL_PASSWORD = os.getenv("FILESS_MYSQL_PASSWORD")
FILESS_MYSQL_DATABASE = os.getenv("FILESS_MYSQL_DATABASE")
FILESS_MYSQL_TABLE = os.getenv("FILESS_MYSQL_DELHI_TABLE")  # table name for all data

csv_folder_path = "/home/neosoft/Desktop/wheather_analytics_trends/data_lake/raw/"
csv_file_paths = glob(os.path.join(csv_folder_path, "*.csv"))

if not csv_file_paths:
    raise FileNotFoundError(f"No CSV files found in folder: {csv_folder_path}")

# ---------- Helper functions ----------
def detect_delimiter(file_path):
    """Detect CSV delimiter dynamically."""
    with open(file_path, 'r', newline='', encoding='utf-8') as f:
        sample = f.read(2048)
        return csv.Sniffer().sniff(sample).delimiter

def clean_value(val):
    if pd.isna(val):
        return None
    val_str = str(val).strip().strip('"').strip("'").replace("(", "").replace(")", "").strip()
    return val_str if val_str != "" else None

def clean_number(val):
    val_clean = clean_value(val)
    if val_clean is None:
        return None
    try:
        return float(val_clean)
    except ValueError:
        print(f"[WARN] Could not convert to float: {val} → cleaned: {val_clean}")
        return None

def parse_date(val):
    val_clean = clean_value(val)
    if not val_clean:
        return None
    try:
        return datetime.strptime(val_clean, '%Y-%m-%d').date()
    except ValueError:
        print(f"[WARN] Could not parse date: {val} → cleaned: {val_clean}")
        return None

def read_csv_with_fallback(file_path):
    """Read CSV, auto-detect delimiter, and handle bad header cases."""
    # First, try normal read with sniffed delimiter
    delimiter = detect_delimiter(file_path)
    df = pd.read_csv(file_path, delimiter=delimiter)

    # If only one column, try splitting manually on comma
    if len(df.columns) == 1:
        print(f"[WARN] File {file_path} has only 1 column after reading. Trying manual split.")
        with open(file_path, 'r', encoding='utf-8') as f:
            first_line = f.readline().strip()
            # Try guessing delimiter from the first line directly
            possible_delims = [',', ';', '\t', '|']
            for delim in possible_delims:
                if delim in first_line:
                    print(f"[INFO] Overriding delimiter to '{delim}' for {file_path}")
                    df = pd.read_csv(file_path, delimiter=delim)
                    break

    return df

def parse_time(val):
    val_clean = clean_value(val)
    if not val_clean:
        return None
    # Try ISO time format first
    try:
        return datetime.strptime(val_clean, "%Y-%m-%dT%H:%M:%S").time()
    except ValueError:
        pass
    # Try space-separated datetime
    try:
        return datetime.strptime(val_clean, "%Y-%m-%d %H:%M:%S").time()
    except ValueError:
        print(f"[WARN] Could not parse time: {val} → cleaned: {val_clean}")
        return None
# --------------------------------------

try:
    connection = mysql.connector.connect(
        host=FILESS_MYSQL_HOST,
        database=FILESS_MYSQL_DATABASE,
        user=FILESS_MYSQL_USER,
        password=FILESS_MYSQL_PASSWORD,
        port=FILESS_MYSQL_PORT
    )

    if connection.is_connected():
        print("✅ Connected to MySQL Server successfully!")
        cursor = connection.cursor()

        for csv_file_path in csv_file_paths:
            print(f"\n📂 Processing file: {csv_file_path}")
            # data = read_csv_with_fallback(csv_file_path)
            # print(f"📊 {len(data)} records found. Columns: {list(data.columns)}")

            # Detect delimiter
            delimiter = detect_delimiter(csv_file_path)
            print(f"🔍 Detected delimiter: '{delimiter}'")

            # Read CSV with correct delimiter
            data = read_csv_with_fallback(csv_file_path)
            total_records = len(data)
            print(f"📊 {len(data)} records found. Columns: {list(data.columns)}")
            print(f"📊 {total_records} records found. Columns: {list(data.columns)}")

            for row_index, row in data.iterrows():
                record = (
                    clean_value(row.get('name')),
                    parse_date(row.get('datetime')),
                    clean_number(row.get('tempmax')),
                    clean_number(row.get('tempmin')),
                    clean_number(row.get('temp')),
                    clean_number(row.get('feelslikemax')),
                    clean_number(row.get('feelslikemin')),
                    clean_number(row.get('feelslike')),
                    clean_number(row.get('dew')),
                    clean_number(row.get('humidity')),
                    clean_number(row.get('precip')),
                    clean_number(row.get('precipprob')),
                    clean_number(row.get('precipcover')),
                    clean_value(row.get('preciptype')),
                    clean_number(row.get('snow')),
                    clean_number(row.get('snowdepth')),
                    clean_number(row.get('windgust')),
                    clean_number(row.get('windspeed')),
                    clean_number(row.get('winddir')),
                    clean_number(row.get('sealevelpressure')),
                    clean_number(row.get('cloudcover')),
                    clean_number(row.get('visibility')),
                    clean_number(row.get('solarradiation')),
                    clean_number(row.get('solarenergy')),
                    clean_number(row.get('uvindex')),
                    clean_number(row.get('severerisk')),
                    parse_time(row.get('sunrise')),
                    parse_time(row.get('sunset')),
                    clean_number(row.get('moonphase')),
                    clean_value(row.get('conditions')),
                    clean_value(row.get('description')),
                    clean_value(row.get('icon')),
                    clean_value(row.get('stations'))
                )

                # Debug output
                print(f"🔍 Row {row_index+1} cleaned record: {record}")

                insert_query = f"""
                INSERT INTO {FILESS_MYSQL_TABLE} (
                    name, datetime, tempmax, tempmin, temp, feelslikemax, feelslikemin, feelslike,
                    dew, humidity, precip, precipprob, precipcover, preciptype, snow, snowdepth,
                    windgust, windspeed, winddir, sealevelpressure, cloudcover, visibility,
                    solarradiation, solarenergy, uvindex, severerisk, sunrise, sunset, moonphase,
                    conditions, description, icon, stations
                ) VALUES ({', '.join(['%s'] * len(record))});
                """

                try:
                    cursor.execute(insert_query, record)
                except Error as e:
                    print(f"[ERROR] Failed to insert row {row_index+1}: {e}")

            connection.commit()
            print(f"✅ Inserted {total_records} records from file {csv_file_path}")

except Error as e:
    print("❌ Error while connecting to MySQL or inserting data:", e)

finally:
    if 'connection' in locals() and connection.is_connected():
        cursor.close()
        connection.close()
        print("🔒 MySQL connection is closed.")
# Out:
# ✅ Connected to MySQL Server successfully!
#
# 📂 Processing file: /home/neosoft/Desktop/wheather_analytics_trends/data_lake/raw/Delhi.csv
# 🔍 Detected delimiter: ','
# [WARN] File /home/neosoft/Desktop/wheather_analytics_trends/data_lake/raw/Delhi.csv has only 1 column after reading. Trying manual split.
# [INFO] Overriding delimiter to ',' for /home/neosoft/Desktop/wheather_analytics_trends/data_lake/raw/Delhi.csv
# 📊 378 records found. Columns: ['name,datetime,tempmax,tempmin,temp,feelslikemax,feelslikemin,feelslike,dew,humidity,precip,precipprob,precipcover,preciptype,snow,snowdepth,windgust,windspeed,winddir,sealevelpressure,cloudcover,visibility,solarradiation,solarenergy,uvindex,severerisk,sunrise,sunset,moonphase,conditions,description,icon,stations']
# 📊 378 records found. Columns: ['name,datetime,tempmax,tempmin,temp,feelslikemax,feelslikemin,feelslike,dew,humidity,precip,precipprob,precipcover,preciptype,snow,snowdepth,windgust,windspeed,winddir,sealevelpressure,cloudcover,visibility,solarradiation,solarenergy,uvindex,severerisk,sunrise,sunset,moonphase,conditions,description,icon,stations']
# 🔍 Row 1 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 2 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 3 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 4 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 5 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 6 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 7 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 8 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 9 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 10 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 11 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 12 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 13 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 14 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 15 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 16 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 17 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 18 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 19 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 20 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 21 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 22 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 23 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 24 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 25 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 26 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 27 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 28 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 29 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 30 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 31 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 32 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 33 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 34 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 35 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 36 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 37 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 38 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 39 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 40 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 41 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 42 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 43 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 44 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 45 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 46 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 47 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 48 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 49 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 50 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 51 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 52 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 53 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 54 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 55 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 56 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 57 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 58 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 59 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 60 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 61 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 62 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 63 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 64 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 65 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 66 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 67 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 68 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 69 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 70 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 71 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 72 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 73 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 74 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 75 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 76 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 77 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 78 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 79 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 80 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 81 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 82 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 83 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 84 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 85 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 86 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 87 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 88 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 89 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 90 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 91 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 92 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 93 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 94 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 95 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 96 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 97 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 98 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 99 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 100 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 101 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 102 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 103 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 104 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 105 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 106 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 107 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 108 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 109 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 110 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 111 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 112 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 113 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 114 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 115 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 116 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 117 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 118 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 119 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 120 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 121 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 122 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 123 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 124 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 125 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 126 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 127 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 128 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 129 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 130 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 131 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 132 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 133 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 134 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 135 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 136 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 137 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 138 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 139 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 140 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 141 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 142 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 143 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 144 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 145 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 146 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 147 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 148 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 149 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 150 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 151 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 152 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 153 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 154 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 155 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 156 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 157 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 158 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 159 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 160 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 161 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 162 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 163 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 164 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 165 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 166 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 167 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 168 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 169 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 170 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 171 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 172 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 173 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 174 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 175 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 176 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 177 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 178 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 179 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 180 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 181 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 182 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 183 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 184 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 185 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 186 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 187 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 188 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 189 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 190 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 191 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 192 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 193 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 194 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 195 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 196 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 197 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 198 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 199 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 200 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 201 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 202 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 203 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 204 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 205 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 206 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 207 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 🔍 Row 208 cleaned record: (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# ...
# 🔍 Row 212 cleaned record: ('Mumbai', datetime.date(2024, 10, 1), 90.9, 80.0, 84.8, 110.0, 85.8, 96.3, 78.2, 81.1, 0.0, 0.0, 0.0, None, 0.0, 0.0, 13.4, 11.4, 314.8, 1007.6, 52.1, 1.6, 235.5, 20.4, 8.0, 75.0, datetime.time(6, 29, 11), datetime.time(18, 26, 48), 0.95, 'Partially cloudy', 'Partly cloudy throughout the day.', 'partly-cloudy-day', '43058099999,VABB,VAJJ,43003099999,43057099999,43060099999')
# 🔍 Row 213 cleaned record: ('Mumbai', datetime.date(2024, 10, 2), 91.4, 82.5, 85.7, 109.6, 92.6, 98.8, 79.0, 80.9, 0.0, 0.0, 0.0, 'rain', 0.0, 0.0, 12.1, 10.2, 262.4, 1008.4, 56.3, 1.4, 254.7, 22.0, 9.0, 60.0, datetime.time(6, 29, 24), datetime.time(18, 25, 57), 0.98, 'Partially cloudy', 'Partly cloudy throughout the day.', 'partly-cloudy-day', 'VABB,VAJJ,43003099999,43057099999,43060099999')
# 🔍 Row 214 cleaned record: ('Mumbai', datetime.date(2024, 10, 3), 90.2, 82.5, 85.3, 103.9, 89.7, 95.3, 76.5, 75.3, 0.0, 0.0, 0.0, 'rain', 0.0, 0.0, 16.8, 9.1, 276.1, 1008.8, 46.7, 1.7, 212.1, 18.3, 7.0, 60.0, datetime.time(6, 29, 37), datetime.time(18, 25, 6), 0.0, 'Partially cloudy', 'Partly cloudy throughout the day.', 'partly-cloudy-day', '43058099999,VABB,VAJJ,43003099999,43057099999,43060099999')
# 🔍 Row 215 cleaned record: ('Mumbai', datetime.date(2024, 10, 4), 90.0, 80.8, 84.5, 103.0, 87.5, 92.7, 75.2, 73.9, 0.0, 0.0, 0.0, 'rain', 0.0, 0.0, 15.7, 11.2, 275.6, 1008.9, 60.5, 1.8, 220.3, 19.1, 8.0, 10.0, datetime.time(6, 29, 51), datetime.time(18, 24, 15), 0.05, 'Partially cloudy', 'Partly cloudy throughout the day.', 'partly-cloudy-day', '43058099999,VABB,VAJJ,43003099999,43057099999,43060099999')
# 🔍 Row 216 cleaned record: ('Mumbai', datetime.date(2024, 10, 5), 89.8, 80.3, 83.9, 100.6, 86.0, 90.8, 74.2, 73.4, 0.0, 0.0, 0.0, 'rain', 0.0, 0.0, 10.1, 11.2, 305.3, 1009.2, 48.0, 1.8, 240.3, 20.8, 8.0, 10.0, datetime.time(6, 30, 4), datetime.time(18, 23, 25), 0.08, 'Partially cloudy', 'Partly cloudy throughout the day.', 'partly-cloudy-day', 'VABB,VAJJ,43003099999,43057099999,43060099999')
# 🔍 Row 217 cleaned record: ('Mumbai', datetime.date(2024, 10, 6), 91.5, 80.0, 84.8, 108.7, 85.2, 93.6, 75.5, 74.4, 0.016, 100.0, 4.17, 'rain', 0.0, 0.0, 28.9, 17.2, 354.8, 1009.1, 54.7, 1.7, 232.1, 20.1, 8.0, 30.0, datetime.time(6, 30, 18), datetime.time(18, 22, 35), 0.12, 'Rain, Partially cloudy', 'Partly cloudy throughout the day with late afternoon rain.', 'rain', 'VABB,VAJJ,43003099999,43057099999,43060099999')
# 🔍 Row 218 cleaned record: ('Mumbai', datetime.date(2024, 10, 7), 94.9, 80.7, 87.1, 108.5, 86.4, 95.3, 74.4, 67.7, 0.0, 0.0, 0.0, None, 0.0, 0.0, 13.2, 8.0, 19.5, 1009.4, 43.3, 1.7, 220.5, 19.2, 8.0, 10.0, datetime.time(6, 30, 33), datetime.time(18, 21, 46), 0.15, 'Partially cloudy', 'Partly cloudy throughout the day.', 'partly-cloudy-day', '43058099999,VABB,VAJJ,43003099999,43057099999,43060099999')
# 🔍 Row 219 cleaned record: ('Mumbai', datetime.date(2024, 10, 8), 94.8, 82.5, 87.0, 109.5, 89.7, 97.2, 75.8, 70.2, 0.0, 0.0, 0.0, None, 0.0, 0.0, 11.6, 9.0, 222.5, 1009.8, 46.0, 1.6, 234.9, 20.3, 9.0, 60.0, datetime.time(6, 30, 48), datetime.time(18, 20, 57), 0.19, 'Partially cloudy', 'Partly cloudy throughout the day.', 'partly-cloudy-day', '43058099999,VABB,VAJJ,43003099999,43057099999,43060099999')
# 🔍 Row 220 cleaned record: ('Mumbai', datetime.date(2024, 10, 9), 86.4, 77.1, 82.0, 99.4, 77.1, 87.7, 75.3, 80.5, 0.315, 100.0, 4.17, 'rain', 0.0, 0.0, 8.7, 8.1, 13.9, 1008.6, 86.2, 1.6, 109.5, 9.4, 5.0, 60.0, datetime.time(6, 31, 3), datetime.time(18, 20, 9), 0.22, 'Rain, Partially cloudy', 'Partly cloudy throughout the day with afternoon rain.', 'rain', '43058099999,VABB,VAJJ,43003099999,43057099999,43060099999')
# 🔍 Row 221 cleaned record: ('Mumbai', datetime.date(2024, 10, 10), 89.3, 75.3, 82.3, 104.9, 75.3, 88.1, 74.7, 78.3, 0.984, 100.0, 4.17, 'rain', 0.0, 0.0, 15.0, 10.1, 328.7, 1006.5, 89.2, 1.6, 149.4, 12.9, 6.0, 30.0, datetime.time(6, 31, 19), datetime.time(18, 19, 21), 0.25, 'Rain, Partially cloudy', 'Partly cloudy throughout the day with late afternoon rain.', 'rain', '43058099999,VABB,VAJJ,43003099999,43057099999,43060099999')
# 🔍 Row 222 cleaned record: ('Mumbai', datetime.date(2024, 10, 11), 92.1, 77.1, 83.4, 108.2, 77.1, 89.3, 74.9, 76.6, 1.063, 100.0, 4.17, 'rain', 0.0, 0.0, 15.9, 10.2, 44.7, 1006.3, 78.9, 1.7, 152.8, 13.1, 6.0, 60.0, datetime.time(6, 31, 34), datetime.time(18, 18, 34), 0.25, 'Rain, Partially cloudy', 'Partly cloudy throughout the day with late afternoon rain.', 'rain', '43058099999,VABB,VAJJ,43003099999,43057099999,43060099999')
# 🔍 Row 223 cleaned record: ('Mumbai', datetime.date(2024, 10, 12), 89.7, 78.9, 83.3, 103.6, 78.9, 90.9, 76.8, 81.4, 0.173, 100.0, 8.33, 'rain', 0.0, 0.0, 14.1, 9.0, 187.9, 1007.3, 73.8, 1.6, 195.7, 16.9, 7.0, 60.0, datetime.time(6, 31, 51), datetime.time(18, 17, 47), 0.32, 'Rain, Partially cloudy', 'Partly cloudy throughout the day with rain.', 'rain', 'VABB,VAJJ,43003099999,43057099999,43060099999')
# 🔍 Row 224 cleaned record: ('Mumbai', datetime.date(2024, 10, 13), 89.9, 78.9, 84.0, 105.0, 78.9, 93.3, 76.9, 79.5, 0.039, 100.0, 4.17, 'rain', 0.0, 0.0, 13.2, 10.3, 271.2, 1008.3, 73.9, 1.7, 239.4, 20.6, 8.0, 60.0, datetime.time(6, 32, 8), datetime.time(18, 17, 1), 0.36, 'Rain, Partially cloudy', 'Partly cloudy throughout the day with late afternoon rain.', 'rain', 'VABB,VAJJ,43003099999,43057099999,43060099999')
# 🔍 Row 225 cleaned record: ('Mumbai', datetime.date(2024, 10, 14), 92.2, 78.9, 83.1, 110.8, 78.9, 89.5, 75.5, 78.5, 0.0, 0.0, 0.0, 'rain', 0.0, 0.0, 13.9, 14.7, 294.1, 1009.0, 79.0, 1.7, 226.6, 19.7, 8.0, 30.0, datetime.time(6, 32, 25), datetime.time(18, 16, 16), 0.39, 'Partially cloudy', 'Partly cloudy throughout the day.', 'partly-cloudy-day', '43058099999,VABB,VAJJ,43003099999,43057099999,43060099999')
# 🔍 Row 226 cleaned record: ('Mumbai', datetime.date(2024, 10, 15), 89.6, 78.5, 83.1, 102.2, 78.5, 89.6, 74.9, 76.9, 0.008, 100.0, 4.17, 'rain', 0.0, 0.0, 12.5, 8.0, 86.3, 1009.0, 77.1, 1.7, 192.8, 16.7, 7.0, 60.0, datetime.time(6, 32, 42), datetime.time(18, 15, 31), 0.42, 'Rain, Partially cloudy', 'Partly cloudy throughout the day with late afternoon rain.', 'rain', '43058099999,VABB,VAJJ,43003099999,43057099999,43060099999')
# 🔍 Row 227 cleaned record: ('Mumbai', datetime.date(2024, 10, 16), 89.6, 78.9, 83.9, 106.9, 78.9, 93.0, 76.6, 79.0, 0.0, 0.0, 0.0, 'rain', 0.0, 0.0, 16.3, 10.2, 267.0, 1008.3, 74.8, 1.6, 181.7, 15.8, 7.0, 60.0, datetime.time(6, 33, 1), datetime.time(18, 14, 47), 0.46, 'Partially cloudy', 'Partly cloudy throughout the day.', 'partly-cloudy-day', '43058099999,VABB,VAJJ,43003099999,43057099999,43060099999')
# 🔍 Row 228 cleaned record: ('Mumbai', datetime.date(2024, 10, 17), 88.7, 80.7, 84.9, 106.1, 87.5, 96.5, 78.0, 80.1, 0.0, 0.0, 0.0, None, 0.0, 0.0, 15.2, 8.0, 271.2, 1007.3, 73.9, 1.6, 116.2, 10.1, 4.0, 60.0, datetime.time(6, 33, 19), datetime.time(18, 14, 4), 0.5, 'Partially cloudy', 'Partly cloudy throughout the day.', 'partly-cloudy-day', '43058099999,VABB,VAJJ,43003099999,43057099999,43060099999')
# 🔍 Row 229 cleaned record: ('Mumbai', datetime.date(2024, 10, 18), 92.4, 82.3, 86.2, 109.9, 89.7, 96.8, 76.6, 73.8, 0.079, 100.0, 4.17, 'rain', 0.0, 0.0, 19.7, 11.4, 167.7, 1007.2, 80.0, 1.7, 173.0, 15.0, 7.0, 60.0, datetime.time(6, 33, 38), datetime.time(18, 13, 21), 0.53, 'Rain, Partially cloudy', 'Partly cloudy throughout the day with late afternoon rain.', 'rain', '43058099999,VABB,VAJJ,43003099999,43057099999,43060099999')
# 🔍 Row 230 cleaned record: ('Mumbai', datetime.date(2024, 10, 19), 89.1, 75.3, 82.3, 105.2, 75.3, 88.0, 75.4, 80.1, 0.393, 100.0, 8.33, 'rain', 0.0, 0.0, 11.0, 11.2, 206.4, 1009.6, 78.7, 1.6, 163.6, 14.1, 6.0, 30.0, datetime.time(6, 33, 58), datetime.time(18, 12, 39), 0.56, 'Rain, Partially cloudy', 'Partly cloudy throughout the day with late afternoon rain.', 'rain', 'VABB,VAJJ,43003099999,43057099999,43060099999')
# 🔍 Row 231 cleaned record: ('Mumbai', datetime.date(2024, 10, 20), 91.8, 77.1, 82.5, 107.0, 77.1, 88.0, 74.5, 77.7, 0.0, 0.0, 0.0, 'rain', 0.0, 0.0, 23.0, 10.3, 311.8, 1010.4, 58.8, 1.7, 201.4, 17.4, 8.0, 60.0, datetime.time(6, 34, 18), datetime.time(18, 11, 58), 0.59, 'Partially cloudy', 'Partly cloudy throughout the day.', 'partly-cloudy-day', 'VABB,VAJJ,43003099999,43057099999,43060099999')
# 🔍 Row 232 cleaned record: ('Mumbai', datetime.date(2024, 10, 21), 92.2, 77.1, 84.3, 105.4, 77.1, 90.2, 73.3, 70.7, 0.0, 0.0, 0.0, 'rain', 0.0, 0.0, 8.7, 8.0, 255.6, 1010.2, 54.8, 1.8, 39.6, 3.4, 2.0, 30.0, datetime.time(6, 34, 38), datetime.time(18, 11, 18), 0.63, 'Partially cloudy', 'Partly cloudy throughout the day.', 'partly-cloudy-day', '43058099999,VABB,VAJJ,43003099999,43057099999,43060099999')
# 🔍 Row 233 cleaned record: ('Mumbai', datetime.date(2024, 10, 22), 93.1, 80.7, 86.0, 110.1, 85.5, 95.4, 75.6, 71.8, 0.0, 0.0, 0.0, None, 0.0, 0.0, 10.1, 11.2, 274.8, 1010.3, 48.7, 1.7, 211.8, 18.3, 8.0, 30.0, datetime.time(6, 34, 59), datetime.time(18, 10, 38), 0.66, 'Partially cloudy', 'Partly cloudy throughout the day.', 'partly-cloudy-day', '43058099999,VABB,VAJJ,43003099999,43057099999,43060099999')
# 🔍 Row 234 cleaned record: ('Mumbai', datetime.date(2024, 10, 23), 94.8, 80.0, 86.6, 106.9, 85.2, 95.6, 75.0, 69.2, 0.0, 0.0, 0.0, None, 0.0, 0.0, 12.8, 12.6, 0.8, 1009.9, 56.5, 1.7, 216.6, 18.7, 8.0, 60.0, datetime.time(6, 35, 21), datetime.time(18, 10), 0.69, 'Partially cloudy', 'Partly cloudy throughout the day.', 'partly-cloudy-day', '43058099999,VABB,VAJJ,43003099999,43057099999,43060099999')
# 🔍 Row 235 cleaned record: ('Mumbai', datetime.date(2024, 10, 24), 94.3, 79.8, 86.9, 107.7, 79.8, 93.8, 72.8, 63.8, 0.0, 0.0, 0.0, None, 0.0, 0.0, 10.3, 9.2, 23.5, 1009.3, 45.0, 1.7, 223.2, 19.4, 8.0, 10.0, datetime.time(6, 35, 43), datetime.time(18, 9, 22), 0.75, 'Partially cloudy', 'Partly cloudy throughout the day.', 'partly-cloudy-day', '43058099999,VABB,VAJJ,43003099999,43057099999,43060099999')
# 🔍 Row 236 cleaned record: ('Mumbai', datetime.date(2024, 10, 25), 94.8, 77.5, 86.2, 104.1, 77.5, 91.7, 72.0, 64.2, 0.0, 0.0, 0.0, None, 0.0, 0.0, 11.4, 9.1, 353.3, 1009.7, 35.3, 1.6, 237.1, 20.5, 8.0, 10.0, datetime.time(6, 36, 5), datetime.time(18, 8, 46), 0.76, 'Partially cloudy', 'Partly cloudy throughout the day.', 'partly-cloudy-day', '43058099999,VABB,VAJJ,43003099999,43057099999,43060099999')
# 🔍 Row 237 cleaned record: ('Mumbai', datetime.date(2024, 10, 26), 94.1, 73.2, 84.6, 102.1, 73.2, 87.1, 67.8, 59.3, 0.0, 0.0, 0.0, None, 0.0, 0.0, 15.7, 11.4, 13.3, 1010.0, 27.9, 1.6, 240.9, 20.8, 8.0, 10.0, datetime.time(6, 36, 29), datetime.time(18, 8, 10), 0.79, 'Partially cloudy', 'Partly cloudy throughout the day.', 'partly-cloudy-day', 'VABB,VAJJ,43003099999,43057099999,43060099999')
# 🔍 Row 238 cleaned record: ('Mumbai', datetime.date(2024, 10, 27), 92.7, 75.3, 85.1, 101.7, 75.3, 90.1, 70.9, 63.4, 0.0, 0.0, 0.0, None, 0.0, 0.0, 13.6, 11.3, 328.7, 1008.7, 12.9, 1.6, 240.1, 20.8, 8.0, 10.0, datetime.time(6, 36, 52), datetime.time(18, 7, 35), 0.83, 'Clear', 'Clear conditions throughout the day.', 'clear-day', 'VABB,VAJJ,43003099999,43057099999,43060099999')
# 🔍 Row 239 cleaned record: ('Mumbai', datetime.date(2024, 10, 28), 91.7, 77.3, 84.9, 104.5, 77.3, 92.4, 75.0, 73.1, 0.0, 0.0, 0.0, None, 0.0, 0.0, 9.8, 11.3, 289.9, 1007.3, 11.1, 1.7, 236.2, 20.4, 8.0, 30.0, datetime.time(6, 37, 17), datetime.time(18, 7, 1), 0.86, 'Clear', 'Clear conditions throughout the day.', 'clear-day', '43058099999,VABB,VAJJ,43003099999,43057099999,43060099999')
# 🔍 Row 240 cleaned record: ('Mumbai', datetime.date(2024, 10, 29), 90.6, 80.5, 85.5, 106.5, 86.4, 96.1, 77.1, 76.7, 0.0, 0.0, 0.0, None, 0.0, 0.0, 14.3, 10.2, 276.0, 1008.6, 43.3, 1.6, 197.5, 17.1, 8.0, 30.0, datetime.time(6, 37, 41), datetime.time(18, 6, 28), 0.89, 'Partially cloudy', 'Partly cloudy throughout the day.', 'partly-cloudy-day', '43058099999,VABB,VAJJ,43003099999,43057099999,43060099999')
# 🔍 Row 241 cleaned record: ('Mumbai', datetime.date(2024, 10, 30), 93.9, 79.2, 85.4, 110.0, 79.2, 94.9, 76.1, 74.6, 0.0, 0.0, 0.0, None, 0.0, 0.0, 8.5, 9.2, 329.4, 1009.3, 33.4, 2.1, 218.8, 18.7, 8.0, 30.0, datetime.time(6, 38, 7), datetime.time(18, 5, 56), 0.92, 'Partially cloudy', 'Partly cloudy throughout the day.', 'partly-cloudy-day', '43058099999,VABB,VAJJ,43003099999,43057099999,remote,43060099999')
# 🔍 Row 242 cleaned record: ('Mumbai', datetime.date(2024, 10, 31), 95.0, 80.1, 87.4, 107.2, 85.7, 94.8, 73.3, 64.7, 0.0, 0.0, 0.0, None, 0.0, 0.0, 12.8, 11.2, 35.2, 1009.7, 23.6, 1.5, 206.2, 17.7, 8.0, 30.0, datetime.time(6, 38, 33), datetime.time(18, 5, 26), 0.96, 'Partially cloudy', 'Partly cloudy throughout the day.', 'partly-cloudy-day', 'VABB,VAJJ,43003099999,43057099999,43060099999')
# 🔍 Row 243 cleaned record: ('Mumbai', datetime.date(2024, 11, 1), 92.9, 76.8, 85.6, 110.0, 76.8, 92.8, 72.6, 66.0, 0.0, 0.0, 0.0, None, 0.0, 0.0, 13.2, 8.1, 255.6, 1011.4, 8.9, 1.6, 212.5, 18.3, 8.0, 10.0, datetime.time(6, 38, 59), datetime.time(18, 4, 56), 0.0, 'Clear', 'Clear conditions throughout the day.', 'clear-day', '43058099999,VABB,VAJJ,43003099999,43057099999,43060099999')
# 🔍 Row 244 cleaned record: ('Mumbai', datetime.date(2024, 11, 2), 96.7, 79.9, 87.3, 101.5, 79.9, 92.3, 70.9, 61.2, 0.0, 0.0, 0.0, None, 0.0, 0.0, 13.6, 6.9, 48.7, 1011.5, 7.7, 1.5, 222.0, 19.1, 8.0, 10.0, datetime.time(6, 39, 26), datetime.time(18, 4, 27), 0.03, 'Clear', 'Clear conditions throughout the day.', 'clear-day', 'VABB,VAJJ,43003099999,43057099999,43060099999')
# 🔍 Row 245 cleaned record: ('Mumbai', datetime.date(2024, 11, 3), 95.3, 75.0, 85.6, 105.0, 75.0, 89.6, 69.4, 60.0, 0.0, 0.0, 0.0, None, 0.0, 0.0, 12.1, 10.2, 66.9, 1011.4, 8.6, 1.8, 231.8, 20.1, 8.0, 10.0, datetime.time(6, 39, 54), datetime.time(18, 4), 0.06, 'Clear', 'Clear conditions throughout the day.', 'clear-day', 'VABB,VAJJ,43003099999,43057099999,43060099999')
# 🔍 Row 246 cleaned record: ('Mumbai', datetime.date(2024, 11, 4), 93.5, 76.7, 86.0, 97.0, 76.7, 88.9, 67.9, 57.1, 0.0, 0.0, 0.0, None, 0.0, 0.0, 14.3, 6.9, 57.0, 1010.6, 20.4, 1.6, 230.5, 19.8, 8.0, 10.0, datetime.time(6, 40, 22), datetime.time(18, 3, 33), 0.1, 'Partially cloudy', 'Partly cloudy throughout the day.', 'partly-cloudy-day', '43058099999,VABB,VAJJ,43003099999,43057099999,43060099999')
# 🔍 Row 247 cleaned record: ('Mumbai', datetime.date(2024, 11, 5), 95.9, 75.7, 86.0, 101.3, 75.7, 88.4, 67.1, 55.2, 0.0, 0.0, 0.0, None, 0.0, 0.0, 12.1, 8.0, 53.1, 1011.1, 13.0, 1.8, 227.7, 19.6, 8.0, 10.0, datetime.time(6, 40, 50), datetime.time(18, 3, 8), 0.13, 'Clear', 'Clear conditions throughout the day.', 'clear-day', '43058099999,VABB,VAJJ,43003099999,43057099999,43060099999')
# 🔍 Row 248 cleaned record: ('Mumbai', datetime.date(2024, 11, 6), 96.2, 75.3, 85.9, 98.5, 75.3, 87.7, 66.1, 54.3, 0.0, 0.0, 0.0, None, 0.0, 0.0, 15.2, 9.2, 60.7, 1012.0, 1.6, 1.8, 229.6, 19.7, 8.0, 10.0, datetime.time(6, 41, 20), datetime.time(18, 2, 44), 0.16, 'Clear', 'Clear conditions throughout the day.', 'clear-day', '43058099999,VABB,VAJJ,43003099999,43057099999,43060099999')
# 🔍 Row 249 cleaned record: ('Mumbai', datetime.date(2024, 11, 7), 96.3, 71.6, 85.0, 98.9, 71.6, 85.5, 62.4, 49.4, 0.0, 0.0, 0.0, None, 0.0, 0.0, 14.1, 8.0, 63.0, 1011.8, 3.7, 1.7, 228.0, 19.7, 8.0, 10.0, datetime.time(6, 41, 49), datetime.time(18, 2, 21), 0.2, 'Clear', 'Clear conditions throughout the day.', 'clear-day', '43058099999,VABB,VAJJ,43003099999,43057099999,43060099999')
# 🔍 Row 250 cleaned record: ('Mumbai', datetime.date(2024, 11, 8), 94.9, 74.1, 84.7, 96.2, 74.1, 85.9, 64.0, 51.7, 0.0, 0.0, 0.0, None, 0.0, 0.0, 13.0, 8.1, 73.7, 1011.6, 3.3, 1.8, 225.8, 19.3, 8.0, 10.0, datetime.time(6, 42, 20), datetime.time(18, 2), 0.23, 'Clear', 'Clear conditions throughout the day.', 'clear-day', '43058099999,VABB,VAJJ,43003099999,43057099999,43060099999')
# ✅ Inserted 250 records from file /home/neosoft/Desktop/wheather_analytics_trends/data_lake/raw/weather data.csv
# 🔒 MySQL connection is closed.
